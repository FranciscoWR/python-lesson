# %%
import urllib.request
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-fc59708d834c> in <module>
#       1 import urllib.request
#       2 import pandas as pd
# ----> 3 import urllib2
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
source_url = "ftp://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Escherichia_coli/reference/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.gff.gz"
gff_file = "E_coli.gff.gz"
gff_data = pd.read_csv(source_url, sep ="/t",comment='#', 
                       names = ["seqid","source","type"])
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in ftp_open(self, req)
#    1566         try:
# -> 1567             fw = self.connect_ftp(user, passwd, host, port, dirs, req.timeout)
#    1568             type = file and 'I' or 'D'
#
# ~\anaconda3\lib\urllib\request.py in connect_ftp(self, user, passwd, host, port, dirs, timeout)
#    1587     def connect_ftp(self, user, passwd, host, port, dirs, timeout):
# -> 1588         return ftpwrapper(user, passwd, host, port, dirs, timeout,
#    1589                           persistent=False)
#
# ~\anaconda3\lib\urllib\request.py in __init__(self, user, passwd, host, port, dirs, timeout, persistent)
#    2408         try:
# -> 2409             self.init()
#    2410         except:
#
# ~\anaconda3\lib\urllib\request.py in init(self)
#    2417         self.ftp = ftplib.FTP()
# ...

# %%
urllib.request.urlretrieve(source_url,gff_file)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in ftp_open(self, req)
#    1566         try:
# -> 1567             fw = self.connect_ftp(user, passwd, host, port, dirs, req.timeout)
#    1568             type = file and 'I' or 'D'
#
# ~\anaconda3\lib\urllib\request.py in connect_ftp(self, user, passwd, host, port, dirs, timeout)
#    1587     def connect_ftp(self, user, passwd, host, port, dirs, timeout):
# -> 1588         return ftpwrapper(user, passwd, host, port, dirs, timeout,
#    1589                           persistent=False)
#
# ~\anaconda3\lib\urllib\request.py in __init__(self, user, passwd, host, port, dirs, timeout, persistent)
#    2408         try:
# -> 2409             self.init()
#    2410         except:
#
# ~\anaconda3\lib\urllib\request.py in init(self)
#    2417         self.ftp = ftplib.FTP()
# ...

# %%
gff_data = pd.read_csv(gff_file, sep ="/t",comment='#', 
                       names = ["seqid","source","type"])
