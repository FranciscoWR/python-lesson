# %%
import urllib.request
import pandas as pd

# %%
source_url = "https://github.com/RabeaMue/Bits_and_pieces_for_the_carpentries_workshops/raw/main/GCF_000005845.2_ASM584v2_genomic.gff.gz"
gff_file = "E_coli.gff.gz"

# %%
urllib.request.urlretrieve(source_url,gff_file)
# Out:
# ('E_coli.gff.gz', <http.client.HTTPMessage at 0x20c8ad15f70>)

# %%
gff_data = pd.read_csv(gff_file,sep = "\t", comment="#",
                      names=["seqid","source","type","start","ende","score","strand","phase","attributes"])

# %%
gff_data
# Out:
#                                                    seqid source  type  start  \
# 0      NC_000913.3\tRefSeq\tregion\t1\t4641652\t.\t+\...   None   NaN    NaN
# 1      NC_000913.3\tRefSeq\tgene\t190\t255\t.\t+\t.\t...   None   NaN    NaN
# 2      NC_000913.3\tRefSeq\tCDS\t190\t255\t.\t+\t0\tI...   None   NaN    NaN
# 3      NC_000913.3\tRefSeq\tgene\t337\t2799\t.\t+\t.\...   None   NaN    NaN
# 4      NC_000913.3\tRefSeq\tCDS\t337\t2799\t.\t+\t0\t...   None   NaN    NaN
# ...                                                  ...    ...   ...    ...
# 10116  NC_000913.3\tRefSeq\tCDS\t4639590\t4640306\t.\...   None   NaN    NaN
# 10117  NC_000913.3\tRefSeq\tgene\t4640402\t4640542\t....   None   NaN    NaN
# 10118  NC_000913.3\tRefSeq\tCDS\t4640402\t4640542\t.\...   None   NaN    NaN
# 10119  NC_000913.3\tRefSeq\tgene\t4640942\t4641628\t....   None   NaN    NaN
# 10120  NC_000913.3\tRefSeq\tCDS\t4640942\t4641628\t.\...   None   NaN    NaN
#
# ...

# %%
urllib.request.urlretrieve(source_url, gff_file)
gff_data = pd.read_csv(gff_file)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-70-541d9fa5d650> in <module>
#       1 urllib.request.urlretrieve(source_url, gff_file)
# ----> 2 gff_data = pd.read_csv(gff_file)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
gff_data["type"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 10116   NaN
# 10117   NaN
# 10118   NaN
# 10119   NaN
# 10120   NaN
# Name: type, Length: 10121, dtype: float64

# %%
gff_data["type"].unique()
# Out:
# array(['region', 'gene', 'CDS', 'repeat_region', 'mobile_genetic_element',
#        'ncRNA', 'exon', 'rRNA', 'tRNA', 'pseudogene', 'sequence_feature',
#        'recombination_feature', 'origin_of_replication'], dtype=object)

# %%
pd.read_csv(gff_file)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-11-e6fe84d342c2> in <module>
# ----> 1 pd.read_csv(gff_file)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
# ...

# %%
pd.read_csv(gff_file)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-12-e6fe84d342c2> in <module>
# ----> 1 pd.read_csv(gff_file)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
# ...

# %%
gff_data[gff_data["type"]]=="genes"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-5a287f7afce7> in <module>
# ----> 1 gff_data[gff_data["type"]]=="genes"
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ...

# %%
gff_data
# Out:
#              seqid  source    type    start     ende score strand phase  \
# 0      NC_000913.3  RefSeq  region        1  4641652     .      +     .
# 1      NC_000913.3  RefSeq    gene      190      255     .      +     .
# 2      NC_000913.3  RefSeq     CDS      190      255     .      +     0
# 3      NC_000913.3  RefSeq    gene      337     2799     .      +     .
# 4      NC_000913.3  RefSeq     CDS      337     2799     .      +     0
# ...            ...     ...     ...      ...      ...   ...    ...   ...
# 10116  NC_000913.3  RefSeq     CDS  4639590  4640306     .      -     0
# 10117  NC_000913.3  RefSeq    gene  4640402  4640542     .      +     .
# 10118  NC_000913.3  RefSeq     CDS  4640402  4640542     .      +     0
# 10119  NC_000913.3  RefSeq    gene  4640942  4641628     .      +     .
# 10120  NC_000913.3  RefSeq     CDS  4640942  4641628     .      +     0
#
#                                               attributes
# ...

# %%
gff_data["type"]
# Out:
# 0        region
# 1          gene
# 2           CDS
# 3          gene
# 4           CDS
#           ...
# 10116       CDS
# 10117      gene
# 10118       CDS
# 10119      gene
# 10120       CDS
# Name: type, Length: 10121, dtype: object

# %%
gff_data["type"]=="gene"
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 10116    False
# 10117     True
# 10118    False
# 10119     True
# 10120    False
# Name: type, Length: 10121, dtype: bool

# %%
gff_data_plus=gff_data[gff_data["strand"]=="+"]

# %%
gff_data["type"].value_counts()
# Out:
# gene                      4419
# CDS                       4379
# repeat_region              697
# exon                       180
# pseudogene                 166
# tRNA                        86
# ncRNA                       72
# mobile_genetic_element      49
# sequence_feature            48
# rRNA                        22
# origin_of_replication        1
# recombination_feature        1
# region                       1
# Name: type, dtype: int64

# %%
gff_data_plus_genes = gff_data_plus[gff_data_plus["type"]=="gene"]

# %%
gff_data_plus_genes
# Out:
#              seqid  source  type    start     ende score strand phase  \
# 1      NC_000913.3  RefSeq  gene      190      255     .      +     .
# 3      NC_000913.3  RefSeq  gene      337     2799     .      +     .
# 5      NC_000913.3  RefSeq  gene     2801     3733     .      +     .
# 7      NC_000913.3  RefSeq  gene     3734     5020     .      +     .
# 9      NC_000913.3  RefSeq  gene     5234     5530     .      +     .
# ...            ...     ...   ...      ...      ...   ...    ...   ...
# 10109  NC_000913.3  RefSeq  gene  4636007  4636696     .      +     .
# 10111  NC_000913.3  RefSeq  gene  4636696  4638120     .      +     .
# 10113  NC_000913.3  RefSeq  gene  4638178  4639530     .      +     .
# 10117  NC_000913.3  RefSeq  gene  4640402  4640542     .      +     .
# 10119  NC_000913.3  RefSeq  gene  4640942  4641628     .      +     .
#
#                                               attributes
# 1      ID=gene-b0001;Dbxref=ASAP:ABE-0000006,ECOCYC:E...
# ...

# %%
gff_data["length"]=gff_data["ende"]-gff_data["start"]+1

# %%
gff_data
# Out:
#              seqid  source    type    start     ende score strand phase  \
# 0      NC_000913.3  RefSeq  region        1  4641652     .      +     .
# 1      NC_000913.3  RefSeq    gene      190      255     .      +     .
# 2      NC_000913.3  RefSeq     CDS      190      255     .      +     0
# 3      NC_000913.3  RefSeq    gene      337     2799     .      +     .
# 4      NC_000913.3  RefSeq     CDS      337     2799     .      +     0
# ...            ...     ...     ...      ...      ...   ...    ...   ...
# 10116  NC_000913.3  RefSeq     CDS  4639590  4640306     .      -     0
# 10117  NC_000913.3  RefSeq    gene  4640402  4640542     .      +     .
# 10118  NC_000913.3  RefSeq     CDS  4640402  4640542     .      +     0
# 10119  NC_000913.3  RefSeq    gene  4640942  4641628     .      +     .
# 10120  NC_000913.3  RefSeq     CDS  4640942  4641628     .      +     0
#
#                                               attributes   length
# ...

# %%
gff_genes = gff_data[gff_data["type"] == "genes"]

# %%
gff_genes
# Out:
# Empty DataFrame
# Columns: [seqid, source, type, start, ende, score, strand, phase, attributes, length]
# Index: []

# %%
gff_data
# Out:
#              seqid  source    type    start     ende score strand phase  \
# 0      NC_000913.3  RefSeq  region        1  4641652     .      +     .
# 1      NC_000913.3  RefSeq    gene      190      255     .      +     .
# 2      NC_000913.3  RefSeq     CDS      190      255     .      +     0
# 3      NC_000913.3  RefSeq    gene      337     2799     .      +     .
# 4      NC_000913.3  RefSeq     CDS      337     2799     .      +     0
# ...            ...     ...     ...      ...      ...   ...    ...   ...
# 10116  NC_000913.3  RefSeq     CDS  4639590  4640306     .      -     0
# 10117  NC_000913.3  RefSeq    gene  4640402  4640542     .      +     .
# 10118  NC_000913.3  RefSeq     CDS  4640402  4640542     .      +     0
# 10119  NC_000913.3  RefSeq    gene  4640942  4641628     .      +     .
# 10120  NC_000913.3  RefSeq     CDS  4640942  4641628     .      +     0
#
#                                               attributes   length
# ...

# %%
gff_genes = gff_data[gff_data["type"] == "gene"]

# %%
gff_genes["length"].mean()
# Out:
# 912.7795881421137

# %%
gff_genes
# Out:
#              seqid  source  type    start     ende score strand phase  \
# 1      NC_000913.3  RefSeq  gene      190      255     .      +     .
# 3      NC_000913.3  RefSeq  gene      337     2799     .      +     .
# 5      NC_000913.3  RefSeq  gene     2801     3733     .      +     .
# 7      NC_000913.3  RefSeq  gene     3734     5020     .      +     .
# 9      NC_000913.3  RefSeq  gene     5234     5530     .      +     .
# ...            ...     ...   ...      ...      ...   ...    ...   ...
# 10111  NC_000913.3  RefSeq  gene  4636696  4638120     .      +     .
# 10113  NC_000913.3  RefSeq  gene  4638178  4639530     .      +     .
# 10115  NC_000913.3  RefSeq  gene  4639590  4640306     .      -     .
# 10117  NC_000913.3  RefSeq  gene  4640402  4640542     .      +     .
# 10119  NC_000913.3  RefSeq  gene  4640942  4641628     .      +     .
#
#                                               attributes  length
# ...

# %%
gff_genes["length"].hist(bins=30,color="black")

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
gff_files_and_source_urls={"S_aureus.gff.gz": "https://github.com/Tillsa/gff_files/raw/master/GCF_000005845.2_ASM584v2_genomic.gff.gz",
"S_typhimurium.gff.gz": "https://github.com/Tillsa/gff_files/raw/master/GCF_000013425.1_ASM1342v1_genomic.gff.gz",
"E_coli.gff.gz":"https://github.com/Tillsa/gff_files/raw/master/GCF_000195995.1_ASM19599v1_genomic.gff.gz"}

# %%
urllib.request.urlretrieve(gff_files_and_source_urls["S_aureus.gff.gz"], "S_aureus.gff.gz")

file = "S_aureus.gff.gz"

# %%
gff_example = pd.read_csv(file)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-63-ef5b4305b3f6> in <module>
# ----> 1 gff_example = pd.read_csv(file)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...

# %%
gff_data = pd.read_csv(file,sep = "/t", comment="#")
# Out:
# <ipython-input-71-6f286e769ca7>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   gff_data = pd.read_csv(file,sep = "/t", comment="#")
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-71-6f286e769ca7> in <module>
# ----> 1 gff_data = pd.read_csv(file,sep = "/t", comment="#")
#
# ...

# %%
import pandas as pd

# %%
gff_data = pd.read_csv(file,sep = "/t", comment="#")
# Out:
# <ipython-input-73-6f286e769ca7>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   gff_data = pd.read_csv(file,sep = "/t", comment="#")
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-73-6f286e769ca7> in <module>
# ----> 1 gff_data = pd.read_csv(file,sep = "/t", comment="#")
#
# ...

# %%
gff_data = pd.read_csv(file)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-74-d3d90a73f4ec> in <module>
# ----> 1 gff_data = pd.read_csv(file)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
# ...

# %%
gff_data = pd.read_csv(file,sep = "/t", comment="#")
# Out:
# <ipython-input-75-6f286e769ca7>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   gff_data = pd.read_csv(file,sep = "/t", comment="#")
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-75-6f286e769ca7> in <module>
# ----> 1 gff_data = pd.read_csv(file,sep = "/t", comment="#")
#
# ...

# %%
gff_data = pd.read_csv(file,sep = "", comment="#")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-8f634582403e> in <module>
# ----> 1 gff_data = pd.read_csv(file,sep = "", comment="#")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
gff_data = pd.read_csv(file,sep = "/t", comment="#")
